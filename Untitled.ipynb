# %%
# Import statements
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import html

# %%
# I want to make a project where I find info about all the courses in UW Madison

# Project started on Nov. 25, 2024

# %% [markdown]
# # Sources
# Source 1 : https://stackoverflow.com/questions/2360598/how-do-i-unescape-html-entities-in-a-string-in-python-3-1/3796917

# %% [markdown]
# # Step 1
# Gather basic information from https://guide.wisc.edu/courses/

# %%
# Setup for course lists
url = "https://guide.wisc.edu/courses/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Get the lists (ul) from the website
    # The lists are inside <div id="atozindex"> == $0
    
data = [] 
    
atoz_div = soup.find('div', id='atozindex')

# Gathers id, abbreviations, name
if atoz_div:
    ul_elements = atoz_div.find_all('ul')
    # The site is set up from A-Z with each letter having a ul for the courses
    for ul in ul_elements:
        items = ul.find_all('li')
        for item in items:
            # this will grab the info inside the href (that holds name and course abbreviations)
                # <li><a href="/courses/acct_i_s/">Accounting and Information Systems (ACCT I S)</a></li>
            pattern = r'<li><a href="/courses/(.*?)/">(.+?) \(([^)]+)\)</a></li>'
            match = re.match(pattern, str(item))
            #print(item)            
            
            if match:
                dep_id = match.group(1) # used for website nav
                dep_name = match.group(2) # naming 
                dep_abbrev = match.group(3) # full name
                
                # SOURCE 1: Fix issue with amps like "ANAT&amp;PHY"
                dep_abbrev = html.unescape(dep_abbrev)
                dep_name = html.unescape(dep_name)
                
                dep_url = f"https://guide.wisc.edu/courses/{dep_id}/"

                data.append({"ID" : dep_id, "ABBREV": dep_abbrev, "DEPARTMENT": dep_name, "URL" : dep_url})

df = pd.DataFrame(data)

# Gather the link for each course using ID 
for course in df["DEPARTMENT"]:
    df["URL"] = "https://guide.wisc.edu/courses/" + df["ID"] + "/"
# for d in df["DEPARTMENT"]:
#     print(d)

df
# Out:
#            ID    ABBREV                          DEPARTMENT  \
# 0    acct_i_s  ACCT I S  Accounting and Information Systems
# 1     act_sci   ACT SCI                   Actuarial Science
# 2    afroamer  AFROAMER            African American Studies
# 3     african   AFRICAN            African Cultural Studies
# 4       a_a_e     A A E  Agricultural and Applied Economics
# ..        ...       ...                                 ...
# 184   surgery   SURGERY                             Surgery
# 185  surg_sci  SURG SCI                   Surgical Sciences
# 186   theatre   THEATRE                   Theatre and Drama
# 187  urb_r_pl  URB R PL         Urban and Regional Planning
# 188   zoology   ZOOLOGY                             Zoology
#
#                                           URL
# 0    https://guide.wisc.edu/courses/acct_i_s/
# 1     https://guide.wisc.edu/courses/act_sci/
# 2    https://guide.wisc.edu/courses/afroamer/
# 3     https://guide.wisc.edu/courses/african/
# 4       https://guide.wisc.edu/courses/a_a_e/
# ..                                        ...
# 184   https://guide.wisc.edu/courses/surgery/
# 185  https://guide.wisc.edu/courses/surg_sci/
# 186   https://guide.wisc.edu/courses/theatre/
# 187  https://guide.wisc.edu/courses/urb_r_pl/
# 188   https://guide.wisc.edu/courses/zoology/
#
# [189 rows x 4 columns]

# %% [markdown]
# # Step 2
# Make code (def) so you can access all the possible courses from a specific DEPARTMENT

# %%
def gather_courses(department):
    """
    Gathers courses for the given department from its URL.

    Parameters:
        department (str): Name of the department to scrape.

    Returns:
        DataFrame: Contains details of courses for the specified department.
    """
    # First, check if the department name is actually in the datafram
    if department in df["DEPARTMENT"].values:
        info = df.loc[df["DEPARTMENT"] == department]
                
        # Get the html loaded from new url
        url = info["URL"].iloc[0]
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        courses = []
        course_blocks = soup.find_all(class_="courseblock")
        
        for course in course_blocks:
            course_details = {}
            
            # TITLE and ID 
            course_title = course.find('p', class_='courseblocktitle').text.strip()
            
            # found issue with Zero Width Space, this is how to fix
            course_title = course_title.replace("\u200B", "")    
            
            pattern = r"([A-Za-z&\-\/\s0-9]+)\s*(\d{3})\s*—\s*(.+)"
            match = re.match(pattern, course_title)
            
            if match:
                #course_details["DEP_COURSE"] = match.group(1)
                course_details["ABBREV"] = str(info["ABBREV"].iloc[0]) + " " + match.group(2)
                course_details["NAME"] = match.group(3)
                course_details["ID"] = int(match.group(2))
            
            # CREDITS (range)
            course_credits = course.find('p', class_='courseblockcredits').text.strip()
            pattern = r"([0-9\-]+)\scredit"
            match = re.match(pattern, course_credits)
            if match:
                course_details["CREDITS"] = match.group(1)
                
            # More info section
                # Load "cb-extras" class from course
            course_extras = course.find('div', class_='cb-extras')
            if course_extras:
                extras = []
                for extra in course_extras.find_all('p', class_='courseblockextra noindent clearfix'):
                    label = extra.find('span', class_='cbextra-label')
                    data = extra.find('span', class_='cbextra-data')
                    if label and data:
                        extras.append(f"{label.text.strip()} {data.text.strip()}")
                course_details["EXTRAS"] = " | ".join(extras)
            else:
                course_details["EXTRAS"] = "None"
            
            
                
            # DESC - Not sure if I should include in df
            course_details["DESCRIPTION"] = course.find("p", class_="courseblockdesc noindent").text.strip()
           
            # append course
            courses.append(course_details)
        
        # return courses
        return pd.DataFrame(courses)
        
    else:
        print("Not in DataFrame")
        return pd.DataFrame()
        
courses_df = gather_courses("Hebrew-Biblical")

courses_df
# Out:
#           ABBREV                                               NAME   ID  \
# 0   HEBR-BIB 103                      ELEMENTARY BIBLICAL HEBREW, I  103
# 1   HEBR-BIB 104                     ELEMENTARY BIBLICAL HEBREW, II  104
# 2   HEBR-BIB 303                      ELEMENTARY BIBLICAL HEBREW, I  303
# 3   HEBR-BIB 304                     ELEMENTARY BIBLICAL HEBREW, II  304
# 4   HEBR-BIB 323                    INTERMEDIATE BIBLICAL HEBREW, I  323
# 5   HEBR-BIB 324                   INTERMEDIATE BIBLICAL HEBREW, II  324
# 6   HEBR-BIB 332                              PROPHETS OF THE BIBLE  332
# 7   HEBR-BIB 391              INTENSIVE ELEMENTARY  BIBLICAL HEBREW  391
# 8   HEBR-BIB 513                             BIBLICAL TEXTS, POETRY  513
# 9   HEBR-BIB 514                             BIBLICAL TEXTS, POETRY  514
# 10  HEBR-BIB 700                    ADVANCED NEAR EASTERN LANGUAGES  700
# 11  HEBR-BIB 701                                          ARAMAIC I  701
# 12  HEBR-BIB 702                                         ARAMAIC II  702
# 13  HEBR-BIB 703                                     UGARITIC TEXTS  703
# 14  HEBR-BIB 704                                 CANAANITE DIALECTS  704
# 15  HEBR-BIB 705                                           SYRIAC I  705
# 16  HEBR-BIB 706                                          SYRIAC II  706
# 17  HEBR-BIB 723  CLASSICAL HEBREW LINGUISTICS:  HISTORICAL AND ...  723
# 18  HEBR-BIB 743                            PENTATEUCHAL NARRATIVES  743
# 19  HEBR-BIB 744                           PENTATEUCHAL LEGAL CODES  744
# 20  HEBR-BIB 751                                 THE BOOK OF ISAIAH  751
# 21  HEBR-BIB 752                                 THE BOOK OF ISAIAH  752
# 22  HEBR-BIB 754                             WISDOM LITERATURE: JOB  754
# 23  HEBR-BIB 755                                             PSALMS  755
# 24  HEBR-BIB 799                                  INDEPENDENT STUDY  799
# 25  HEBR-BIB 951                           SEMINAR-BIBLICAL STUDIES  951
# 26  HEBR-BIB 990                                RESEARCH AND THESIS  990
#
#    CREDITS                                             EXTRAS  \
# 0        4  Requisites: None | Course Designation: Frgn La...
# 1        4  Requisites: HEBR-BIB 103 | Course Designation:...
# 2        3  Requisites: Graduate/professional standing | R...
# 3        3  Requisites: HEBR-BIB 303 | Repeatable for Cred...
# 4        4  Requisites: HEBR-BIB 104, 304, or graduate/pro...
# 5        4  Requisites: HEBR-BIB 323 or graduate/professio...
# 6        4  Requisites: RELIG ST/​CLASSICS/​JEWISH/​LITTRA...
# 7        4  Requisites: Not open to students with credit f...
# 8        3  Requisites: HEBR-BIB 324 | Course Designation:...
# 9        3  Requisites: HEBR-BIB/​JEWISH  513 | Course Des...
# 10       3  Requisites: Graduate/professional standing | C...
# 11       3  Requisites: Graduate/professional standing | C...
# 12       3  Requisites: Graduate/professional standing | C...
# 13       3  Requisites: Graduate/professional standing | C...
# 14       3  Requisites: Graduate/professional standing | C...
# 15       3  Requisites: Graduate/professional standing | C...
# 16       3  Requisites: Graduate/professional standing | C...
# 17       3  Requisites: Graduate/professional standing | C...
# 18       3  Requisites: Graduate/professional standing | C...
# 19       3  Requisites: Graduate/professional standing | C...
# 20       3  Requisites: Graduate/professional standing | C...
# 21       3  Requisites: Graduate/professional standing | C...
# 22       3  Requisites: Graduate/professional standing | C...
# 23       3  Requisites: Graduate/professional standing | C...
# 24     1-3  Requisites: Consent of instructor | Course Des...
# 25       2  Requisites: Graduate/professional standing | C...
# 26     2-9  Requisites: Consent of instructor | Course Des...
#
#                                           DESCRIPTION
# 0   Introduction to the language of the Hebrew Bib...
# 1   Introduction to the language of the Hebrew Bib...
# 2   Forms and syntax, reading of Classical Hebrew ...
# 3   Forms and syntax, reading of Classical Hebrew ...
# 4   Review of grammar, introduction to reading nar...
# 5   Review of grammar, introduction to reading nar...
# 6   An introduction to the thought, literature, an...
# 7   An intensive introduction to the grammar and v...
# 8   Critical reading of selected texts from the Mi...
# 9   Critical reading of selected texts from the La...
# 10  Provides graduate-level instruction in languag...
# 11  Grammar and readings in Biblical Aramaic (Dani...
# 12  Selections from non-biblical Aramaic texts: In...
# 13  Readings in mythological, administrative, and ...
# 14  Phoenician, Punic, Moabite, and Hebrew epigrap...
# 15                        Syriac grammar and reading.
# 16              Readings in Peshitta, literary texts.
# 17  The phonology, morphology and syntax of biblic...
# 18  Philological and literary study of the Hebrew ...
# 19  A philological and comparative study, in Hebre...
# 20  Philological and literary study of the Hebrew ...
# 21  Philological and literary study of the Hebrew ...
# 22  Philological and literary study of the Hebrew ...
# 23  Philological and linguistic study of the Book ...
# 24  Independent study as arranged with a faculty m...
# 25  Examine topics relevant to Biblical Studies th...
# 26  Individual study for research and completing t...

# %% [markdown]
# # Part 3
# Make CSV of all courses after implemting all of step 2
